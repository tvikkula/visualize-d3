# %%
import csv
import pprint
baseballdata = {}
with open('data/baseball_data.csv', mode='r') as csvfile:
    reader = csv.reader(csvfile)
    data = dict((rows[0],rows[1]) for rows in reader)
pprint.pprint(data)
# Out:
# {'Adolfo Phillips': 'R',
#  'Al Bumbry': 'L',
#  'Al Cowens': 'R',
#  'Al Downing': 'R',
#  'Al Ferrara': 'R',
#  'Al Gallagher': 'R',
#  'Al Jones': 'R',
#  'Al Lachowicz': 'R',
#  'Al Luplow': 'L',
#  'Al Oliver': 'L',
#  'Al Weis': 'B',
#  'Al Woods': 'L',
#  'Alan Ashby': 'B',
#  'Alan Bannister': 'R',
#  'Alan Knicely': 'R',
#  'Alan Wiggins': 'B',
#  'Alan Wirth': 'R',
#  'Albert Hall': 'B',
#  'Albert Williams': 'R',
#  'Alex Johnson': 'R',
#  'Alex Sanchez': 'R',
#  'Alex Trevino': 'R',
#  'Alfredo Martinez': 'R',
#  'Allan Ramirez': 'R',
#  'Amos Otis': 'R',
#  'Andre Robertson': 'R',
#  'Andre Thornton': 'R',
#  'Andres Mora': 'R',
#  'Andres Thomas': 'R',
#  'Andy Beene': 'R',
#  'Andy Etchebarren': 'R',
#  'Andy Kosco': 'R',
#  'Andy Messersmith': 'R',
#  'Andy Replogle': 'R',
#  'Angel Mangual': 'R',
#  'Angel Moreno': 'L',
#  'Angel Salazar': 'R',
#  'Art Howe': 'R',
#  'Art Shamsky': 'L',
#  'Aurelio Rodriguez': 'R',
#  'Bake McBride': 'L',
#  'Barbaro Garbey': 'R',
#  'Barry Bonnell': 'R',
#  'Barry Cort': 'R',
#  'Barry Evans': 'R',
#  'Barry Foote': 'R',
#  'Barry Raziano': 'B',
#  'Ben Callahan': 'R',
#  'Ben Oglivie': 'L',
#  'Benny Ayala': 'R',
#  'Bernie Allen': 'L',
#  'Bernie Carbo': 'L',
#  'Bert Bradley': 'B',
#  'Bert Campaneris': 'R',
#  'Biff Pocoroba': 'B',
#  'Bill Almon': 'R',
#  'Bill Buckner': 'L',
#  'Bill Castro': 'R',
#  'Bill Fahey': 'L',
#  'Bill Freehan': 'R',
#  'Bill Fulton': 'R',
#  'Bill Madlock': 'R',
#  'Bill Melton': 'R',
#  'Bill Mooneyham': 'R',
#  'Bill Moran': 'R',
#  'Bill Nahorodny': 'R',
#  'Bill Paschall': 'R',
#  'Bill Plummer': 'R',
#  'Bill Robinson': 'R',
#  'Bill Russell': 'R',
#  'Bill Sample': 'R',
#  'Bill Schroeder': 'R',
#  'Bill Sharp': 'L',
#  'Bill Stein': 'R',
#  'Bill Sudakis': 'B',
#  'Bill Voss': 'L',
#  'Bill Wilkinson': 'R',
#  'Billy Bryan': 'L',
#  'Billy Conigliaro': 'R',
#  'Billy Cowan': 'R',
#  'Billy Grabarkewitz': 'R',
#  'Billy North': 'B',
#  'Billy Smith': 'B',
#  'Bo Diaz': 'R',
#  'Bob Babcock': 'R',
#  'Bob Bailey': 'R',
#  'Bob Bailor': 'R',
#  'Bob Barton': 'R',
#  'Bob Boone': 'R',
#  'Bob Brenly': 'R',
#  'Bob Brower': 'R',
#  'Bob Burda': 'L',
#  'Bob Chance': 'L',
#  'Bob Coluccio': 'R',
#  'Bob Davidson': 'R',
#  'Bob Davis': 'R',
#  'Bob Dernier': 'R',
#  'Bob Didier': 'B',
#  'Bob Fallon': 'L',
#  'Bob Ferris': 'R',
#  'Bob Forsch': 'R',
#  'Bob Galasso': 'L',
#  'Bob Heise': 'R',
#  'Bob Horner': 'R',
#  'Bob Johnson': 'R',
#  'Bob Jones': 'L',
#  'Bob Kammeyer': 'R',
#  'Bob Kearney': 'R',
#  'Bob Knepper': 'L',
#  'Bob Meacham': 'B',
#  'Bob Molinaro': 'L',
#  'Bob Montgomery': 'R',
#  'Bob Oliver': 'R',
#  'Bob Randall': 'R',
#  'Bob Robertson': 'R',
#  'Bob Stinson': 'B',
#  'Bob Tillman': 'R',
#  'Bob Uecker': 'R',
#  'Bob Veale': 'B',
#  'Bob Veselic': 'R',
#  'Bob Watson': 'R',
#  'Bobby Bonds': 'R',
#  'Bobby Brown': 'B',
#  'Bobby Clark': 'R',
#  'Bobby Cox': 'R',
#  'Bobby Cuellar': 'R',
#  'Bobby Darwin': 'R',
#  'Bobby Grich': 'R',
#  'Bobby Klaus': 'R',
#  'Bobby Knoop': 'R',
#  'Bobby Mitchell': 'R',
#  'Bobby Murcer': 'L',
#  'Bobby Tolan': 'L',
#  'Bobby Valentine': 'R',
#  'Bobby Wine': 'R',
#  'Bombo Rivera': 'R',
#  'Boog Powell': 'L',
#  'Boots Day': 'L',
#  'Brad Wellman': 'R',
#  'Brant Alyea': 'R',
#  'Brian Allard': 'R',
#  'Brian Asselstine': 'L',
#  'Brian Denman': 'R',
#  'Brian Dubois': 'L',
#  'Brian Giles': 'R',
#  'Brian Snyder': 'L',
#  'Britt Burns': 'L',
#  'Brock Davis': 'L',
#  'Broderick Perkins': 'L',
#  'Bruce Benedict': 'R',
#  'Bruce Bochte': 'L',
#  'Bruce Bochy': 'R',
#  'Bruce Boisclair': 'L',
#  'Bruce Ellingsen': 'L',
#  'Bruce Miller': 'R',
#  'Bruce Robbins': 'L',
#  'Bruce Tanner': 'L',
#  'Bruce Taylor': 'R',
#  'Bryan Clutterbuck': 'R',
#  'Bryan Kelly': 'R',
#  'Bryan Little': 'B',
#  'Bryan Oelkers': 'L',
#  'Bubba Morton': 'R',
#  'Buck Martinez': 'R',
#  'Buck Rodgers': 'B',
#  'Bucky Dent': 'R',
#  'Bud Anderson': 'R',
#  'Bud Harrelson': 'B',
#  'Buddy Bell': 'R',
#  'Buddy Biancalana': 'B',
#  'Buddy Bradford': 'R',
#  'Bump Wills': 'B',
#  'Burt Hooton': 'R',
#  'Butch Edge': 'R',
#  'Butch Hobson': 'R',
#  'Butch Wynegar': 'B',
#  'Byron Browne': 'R',
#  'Byron McLaughlin': 'R',
#  'Cap Peterson': 'R',
#  'Cardell Camper': 'R',
#  'Carl Morton': 'R',
#  'Carl Taylor': 'R',
#  'Carl Warwick': 'R',
#  'Carl Yastrzemski': 'L',
#  'Carlos May': 'L',
#  'Carlos Velazquez': 'R',
#  'Carmen Fanzone': 'R',
#  'Catfish Hunter': 'R',
#  'Cecil Cooper': 'L',
#  'Cesar Cedeno': 'R',
#  'Cesar Geronimo': 'L',
#  'Cesar Gutierrez': 'R',
#  'Cesar Tovar': 'R',
#  'Champ Summers': 'L',
#  'Charley Smith': 'R',
#  'Charlie James': 'R',
#  'Charlie Mitchell': 'R',
#  'Charlie Moore': 'R',
#  'Charlie Spikes': 'R',
#  'Chet Lemon': 'R',
#  'Chico Escarrega': 'R',
#  'Chico Ruiz': 'B',
#  'Chico Salmon': 'R',
#  'Chris Bando': 'B',
#  'Chris Batton': 'R',
#  'Chris Brown': 'R',
#  'Chris Cannizzaro': 'R',
#  'Chris Chambliss': 'L',
#  'Chris Knapp': 'R',
#  'Chris Speier': 'R',
#  'Chuck Harrison': 'R',
#  'Chuck Hiller': 'L',
#  'Chuck Hinton': 'R',
#  'Chuck Hockenbery': 'B',
#  'Chuck Porter': 'R',
#  'Chuck Schilling': 'R',
#  'Cito Gaston': 'R',
#  'Claudell Washington': 'L',
#  'Clay Christiansen': 'R',
#  'Clay Dalrymple': 'L',
#  'Cleon Jones': 'R',
#  'Cliff Johnson': 'R',
#  'Clint Hurdle': 'L',
#  'Clint Zavaras': 'R',
#  'Coco Laboy': 'R',
#  'Colby Ward': 'R',
#  'Cookie Rojas': 'R',
#  'Craig Chamberlain': 'R',
#  'Craig Eaton': 'R',
#  'Craig Kusick': 'R',
#  'Craig Mitchell': 'R',
#  'Craig Reynolds': 'L',
#  'Craig Robinson': 'R',
#  'Curt Blefary': 'L',
#  'Curt Ford': 'L',
#  'Curt Kaufman': 'R',
#  'Curt Motton': 'R',
#  'Curt Wardle': 'L',
#  'Dal Maxvill': 'R',
#  'Dale Berra': 'R',
#  'Dalton Jones': 'L',
#  'Damaso Garcia': 'R',
#  'Dan Briggs': 'L',
#  'Dan Driessen': 'L',
#  'Dan Ford': 'R',
#  'Dan Meyer': 'L',
#  'Dan Morogiello': 'L',
#  'Dane Iorg': 'L',
#  'Danny Ainge': 'R',
#  'Danny Cater': 'R',
#  'Danny Fife': 'R',
#  'Danny Goodwin': 'L',
#  'Danny Thompson': 'R',
#  'Danny Walton': 'R',
#  'Darrel Chaney': 'B',
#  'Darrell Brown': 'B',
#  'Darrell Evans': 'L',
#  'Darrell Porter': 'L',
#  'Darryl Motley': 'R',
#  'Daryl Sconiers': 'L',
#  'Daryl Smith': 'R',
#  'Dave Campbell': 'R',
#  'Dave Cash': 'R',
#  'Dave Chalk': 'R',
#  'Dave Collins': 'B',
#  'Dave Concepcion': 'R',
#  'Dave Duncan': 'R',
#  'Dave Edwards': 'R',
#  'Dave Engle': 'R',
#  'Dave Ford': 'R',
#  'Dave Frost': 'R',
#  'Dave Hilton': 'R',
#  'Dave Hostetler': 'R',
#  'Dave Johnson': 'R',
#  'Dave Kingman': 'R',
#  'Dave Lemanczyk': 'R',
#  'Dave Marshall': 'L',
#  'Dave May': 'L',
#  'Dave McKay': 'B',
#  'Dave McNally': 'R',
#  'Dave Nelson': 'R',
#  'Dave Nicholson': 'R',
#  'Dave Rader': 'L',
#  'Dave Rajsich': 'L',
#  'Dave Revering': 'L',
#  'Dave Roberts': 'L',
#  'Dave Rosello': 'R',
#  'Dave Skaggs': 'R',
#  'Dave Smith': 'R',
#  'Dave Stapleton': 'R',
#  'Davey Johnson': 'R',
#  'Davey Lopes': 'R',
#  'David Green': 'R',
#  'De Wayne Buice': 'R',
#  'De Wayne Vaughn': 'R',
#  'Dean Chance': 'R',
#  'Del Unser': 'L',
#  'Denis Menke': 'R',
#  'Dennis Burtt': 'R',
#  'Dennis DeBarr': 'L',
#  'Denny Doyle': 'L',
#  'Denny Lemaster': 'R',
#  'Denny McLain': 'R',
#  'Deron Johnson': 'R',
#  'Derrel Thomas': 'B',
#  'Dewey Robinson': 'R',
#  'Dick Allen': 'R',
#  'Dick Bertell': 'R',
#  'Dick Billings': 'R',
#  'Dick Davis': 'R',
#  'Dick Dietz': 'R',
#  'Dick Green': 'R',
#  'Dick Howser': 'R',
#  'Dick McAuliffe': 'L',
#  'Dick Nen': 'L',
#  'Dick Phillips': 'L',
#  'Dick Ruthven': 'R',
#  'Dick Simpson': 'R',
#  'Dick Tracewski': 'R',
#  'Doc Edwards': 'R',
#  'Domingo Ramos': 'R',
#  'Don Baylor': 'R',
#  'Don Buford': 'B',
#  'Don Cooper': 'R',
#  'Don Gordon': 'R',
#  'Don Hahn': 'R',
#  'Don Kainer': 'R',
#  'Don Kessinger': 'B',
#  'Don Leppert': 'R',
#  'Don Lock': 'R',
#  'Don Mason': 'L',
#  'Don Mincher': 'L',
#  'Don Money': 'R',
#  'Don Sutton': 'R',
#  'Don Welchel': 'R',
#  'Don Wert': 'R',
#  'Don Wilson': 'R',
#  'Donn Clendenon': 'R',
#  'Doug Ault': 'R',
#  'Doug Camilli': 'R',
#  'Doug Clemens': 'L',
#  'Doug DeCinces': 'R',
#  'Doug Flynn': 'R',
#  'Doug Frobel': 'L',
#  'Doug Griffin': 'R',
#  'Doug Rader': 'R',
#  'Duane Josephson': 'R',
#  'Duane Kuiper': 'L',
#  'Duane Walker': 'L',
#  'Duffy Dyer': 'R',
#  'Duke Sims': 'L',
#  'Dusty Baker': 'R',
#  'Dwayne Murphy': 'L',
#  'Earl Williams': 'R',
#  'Ed Brinkman': 'R',
#  'Ed Charles': 'R',
#  'Ed Crosby': 'L',
#  'Ed Goodson': 'L',
#  'Ed Herrmann': 'L',
#  'Ed Hodge': 'L',
#  'Ed Kirkpatrick': 'L',
#  'Ed Kranepool': 'L',
#  'Ed Ott': 'L',
#  'Ed Romero': 'R',
#  'Ed Spiezio': 'R',
#  'Ed Stroud': 'L',
#  'Eddie Leon': 'R',
#  'Eddie Milner': 'L',
#  'Elio Chacon': 'R',
#  'Ellie Hendricks': 'L',
#  'Ellie Rodriguez': 'R',
#  'Elliott Maddox': 'R',
#  'Ellis Valentine': 'R',
#  'Enos Cabell': 'R',
#  'Enzo Hernandez': 'R',
#  'Eric Hetzel': 'R',
#  'Eric Soderholm': 'R',
#  'Eric Wilkins': 'R',
#  'Felix Millan': 'R',
#  'Felix Torres': 'R',
#  'Fergie Jenkins': 'R',
#  'Fernando Arroyo': 'R',
#  'Fernando Gonzalez': 'R',
#  'Floyd Rayford': 'R',
#  'Floyd Robinson': 'L',
#  'Fran Healy': 'R',
#  'Francisco Barrios': 'R',
#  'Frank Dimichele': 'R',
#  'Frank Duffy': 'R',
#  'Frank Eufemia': 'R',
#  'Frank Fernandez': 'R',
#  'Frank Quilici': 'R',
#  'Frank Taveras': 'R',
#  'Frank Tepedino': 'L',
#  'Frank White': 'R',
#  'Fred Howard': 'R',
#  'Fred Kendall': 'R',
#  'Fred Lynn': 'L',
#  'Fred Norman': 'B',
#  'Fred Stanley': 'R',
#  'Fred Whitfield': 'L',
#  'Freddie Patek': 'R',
#  'Fritz Peterson': 'B',
#  'Gail Hopkins': 'L',
#  'Garry Hancock': 'L',
#  'Garry Maddox': 'R',
#  'Garth Iorg': 'R',
#  'Gary Alexander': 'R',
#  'Gary Allenson': 'R',
#  'Gary Beare': 'R',
#  'Gary Christenson': 'L',
#  'Gary Gray': 'R',
#  'Gary Ignasiak': 'R',
#  'Gary Lance': 'B',
#  'Gary Matthews': 'R',
#  'Gary Mielke': 'R',
#  'Gary Nolan': 'R',
#  'Gary Roenicke': 'R',
#  'Gary Sutherland': 'R',
#  'Gary Thomasson': 'L',
#  'Gary Ward': 'R',
#  'Gary Wheelock': 'R',
#  'Gary Woods': 'R',
#  'Gates Brown': 'L',
#  'Gaylord Perry': 'R',
#  'Gene Alley': 'R',
#  'Gene Clines': 'R',
#  'Gene Locklear': 'L',
#  'Gene Michael': 'B',
#  'Gene Richards': 'L',
#  'Gene Tenace': 'R',
#  'George Foster': 'R',
#  'George Hendrick': 'R',
#  'George Mitterwald': 'R',
#  'George Scott': 'R',
#  'George Smith': 'R',
#  'George Vukovich': 'L',
#  'George Wright': 'B',
#  'Gil Garrido': 'R',
#  'Gil Patterson': 'R',
#  'Glen Cook': 'R',
#  'Glenn Adams': 'L',
#  'Glenn Beckert': 'R',
#  'Glenn Borgmann': 'R',
#  'Glenn Burke': 'R',
#  'Glenn Hoffman': 'R',
#  'Glenn Hubbard': 'R',
#  'Gorman Heimueller': 'L',
#  'Gorman Thomas': 'R',
#  'Graig Nettles': 'L',
#  'Greg Erardi': 'R',
#  'Greg Gross': 'L',
#  'Greg Luzinski': 'R',
#  'Greg Pryor': 'R',
#  'Greg Thayer': 'R',
#  'Greg Walker': 'L',
#  'Hal Breeden': 'R',
#  'Hal King': 'L',
#  'Hal Lanier': 'R',
#  'Hal McRae': 'R',
#  'Hank Allen': 'R',
#  'Harry Spilman': 'L',
#  'Hector Cruz': 'R',
#  'Hector Torres': 'R',
#  'Horace Clarke': 'B',
#  'Hosken Powell': 'L',
#  'Howard Bailey': 'R',
#  'Howie Goss': 'R',
#  'Ike Brookens': 'R',
#  'Ike Brown': 'R',
#  'Israel Sanchez': 'L',
#  'Ivan DeJesus': 'R',
#  'Ivan Murrell': 'R',
#  'J.R. Richard': 'R',
#  'Jack Billingham': 'R',
#  'Jack Brohamer': 'L',
#  'Jack Hardy': 'R',
#  'Jack Heidemann': 'R',
#  'Jack Hiatt': 'R',
#  'Jack Lazorko': 'R',
#  'Jack Perconte': 'L',
#  'Jackie Gutierrez': 'R',
#  'Jackie Hernandez': 'R',
#  'Jaime Cocanower': 'R',
#  'Jake Gibbs': 'L',
#  'Jake Wood': 'R',
#  'Jason Thompson': 'L',
#  'Jay Johnstone': 'L',
#  'Jay Pettibone': 'R',
#  'Jeff Barkley': 'B',
#  'Jeff Bettendorf': 'R',
#  'Jeff Burroughs': 'R',
#  'Jeff Byrd': 'R',
#  'Jeff Holly': 'L',
#  'Jeff Jones': 'R',
#  'Jeff Newman': 'R',
#  'Jeff Peterek': 'R',
#  'Jeff Richardson': 'R',
#  'Jeff Rineer': 'L',
#  'Jeff Schattinger': 'L',
#  'Jeff Schneider': 'B',
#  'Jeff Sellers': 'R',
#  'Jeff Shaver': 'R',
#  'Jeff Stone': 'L',
#  'Jeff Torborg': 'R',
#  'Jeff Twitty': 'L',
#  'Jeffrey Leonard': 'R',
#  'Jerry Augustine': 'L',
#  'Jerry Buchek': 'R',
#  'Jerry Dybzinski': 'R',
#  'Jerry Garvin': 'L',
#  'Jerry Grote': 'R',
#  'Jerry Hairston': 'B',
#  'Jerry Kenney': 'L',
#  'Jerry Koosman': 'R',
#  'Jerry Kutzler': 'L',
#  'Jerry Martin': 'R',
#  'Jerry May': 'R',
#  'Jerry McNertney': 'R',
#  'Jerry Morales': 'R',
#  'Jerry Moses': 'R',
#  'Jerry Mumphrey': 'B',
#  'Jerry Narron': 'L',
#  'Jerry Remy': 'L',
#  'Jerry Reuss': 'L',
#  'Jerry Royster': 'R',
#  'Jerry Terrell': 'R',
#  'Jerry Turner': 'L',
#  'Jerry Ujdur': 'R',
#  'Jerry White': 'B',
#  'Jerry Zimmerman': 'R',
#  'Jesse Gonder': 'L',
#  'Jesus Alou': 'R',
#  'Jim Anderson': 'R',
#  'Jim Barr': 'R',
#  'Jim Beauchamp': 'R',
#  'Jim Burton': 'R',
#  'Jim Campbell': 'L',
#  'Jim Dorsey': 'R',
#  'Jim Dwyer': 'L',
#  'Jim Essian': 'R',
#  'Jim Fairey': 'L',
#  'Jim Farr': 'R',
#  'Jim Fregosi': 'R',
#  'Jim French': 'L',
#  'Jim Gideon': 'R',
#  'Jim Gosger': 'L',
#  'Jim Hickman': 'R',
#  'Jim Holt': 'L',
#  'Jim Lefebvre': 'B',
#  'Jim Lewis': 'R',
#  'Jim Lonborg': 'R',
#  'Jim Lyttle': 'L',
#  'Jim Maloney': 'L',
#  'Jim Mason': 'L',
#  'Jim Morrison': 'R',
#  'Jim Nettles': 'L',
#  'Jim Norris': 'L',
#  'Jim Northrup': 'L',
#  'Jim Pankovits': 'R',
#  'Jim Price': 'R',
#  'Jim Ray Hart': 'R',
#  'Jim Rice': 'R',
#  'Jim Rooker': 'R',
#  'Jim Siwy': 'R',
#  'Jim Spencer': 'L',
#  'Jim Sundberg': 'R',
#  'Jim Traber': 'L',
#  'Jim Umbarger': 'L',
#  'Jim Wohlford': 'R',
#  'Jim Wright': 'R',
#  'Jimmie Hall': 'L',
#  'Jimmie Schaffer': 'R',
#  'Jimmy Stewart': 'B',
#  'Jimmy Wynn': 'R',
#  'Joaquin Andujar': 'B',
#  'Jody Davis': 'R',
#  'Joe Azcue': 'R',
#  'Joe Charboneau': 'R',
#  'Joe Ferguson': 'R',
#  'Joe Foy': 'R',
#  'Joe Gaines': 'R',
#  'Joe Hague': 'L',
#  'Joe Horlen': 'R',
#  'Joe Keough': 'L',
#  'Joe Lahoud': 'L',
#  'Joe Lefebvre': 'L',
#  'Joe Lis': 'R',
#  'Joe Lovitto': 'B',
#  'Joe Morgan': 'L',
#  'Joe Niekro': 'R',
#  'Joe Nolan': 'L',
#  'Joe Nossek': 'R',
#  'Joe Pactwa': 'L',
#  'Joe Pepitone': 'L',
#  'Joe Rudi': 'R',
#  'Joe Simpson': 'L',
#  'Joe Skalski': 'R',
#  'Joe Strain': 'R',
#  'Joe Torre': 'R',
#  'Joe Wallis': 'B',
#  'Joel Davis': 'L',
#  'Joel McKeon': 'L',
#  'Joel Youngblood': 'R',
#  'John Bateman': 'R',
#  'John Boccabella': 'R',
#  'John Bohnet': 'B',
#  'John Butcher': 'R',
#  'John Caneira': 'R',
#  'John Castino': 'R',
#  'John Denny': 'R',
#  'John Donaldson': 'L',
#  'John Ellis': 'R',
#  'John Flinn': 'R',
#  'John Hale': 'L',
#  'John Hobbs': 'R',
#  'John Hoover': 'R',
#  'John Kennedy': 'R',
#  'John LaRose': 'L',
#  'John Leister': 'R',
#  'John Lowenstein': 'L',
#  'John Mayberry': 'L',
#  'John Milner': 'L',
#  'John Orsino': 'R',
#  'John Pawlowski': 'R',
#  'John Poloni': 'L',
#  'John Stearns': 'R',
#  'John Stephenson': 'L',
#  'John Trautwein': 'R',
#  'John Vukovich': 'R',
#  'John Wathan': 'R',
#  'John Wockenfuss': 'R',
#  'Johnnie LeMaster': 'R',
#  'Johnny Bench': 'R',
#  'Johnny Briggs': 'L',
#  'Johnny Edwards': 'L',
#  'Johnny Grubb': 'L',
#  'Johnny Jeter': 'R',
#  'Johnny Lewis': 'L',
#  'Johnny Oates': 'L',
#  'Johnny Ray': 'B',
#  'Jorge Orta': 'L',
#  'Jose Arcia': 'R',
#  'Jose Cardenal': 'R',
#  'Jose Cecena': 'R',
#  'Jose Cruz': 'L',
#  'Jose Morales': 'R',
#  'Jose Roman': 'R',
#  'Jose Tartabull': 'L',
#  'Juan Beniquez': 'R',
#  'Juan Bonilla': 'R',
#  'Juan Marichal': 'R',
#  'Juan Nieves': 'L',
#  'Julian Javier': 'R',
#  'Julio Cruz': 'B',
#  'Julio Gonzalez': 'R',
#  'Julio Gotay': 'R',
#  'Junior Kennedy': 'R',
#  'Junior Moore': 'R',
#  'Karl Best': 'R',
#  'Keith Creel': 'R',
#  'Keith Hernandez': 'L',
#  'Keith Macwhorter': 'R',
#  'Keith Moreland': 'R',
#  'Ken Berry': 'R',
#  'Ken Boswell': 'L',
#  'Ken Gerhart': 'R',
#  'Ken Harrelson': 'R',
#  'Ken Henderson': 'B',
#  'Ken Holtzman': 'R',
#  'Ken Hubbs': 'R',
#  'Ken Landreaux': 'L',
#  'Ken McMullen': 'R',
#  'Ken Phelps': 'L',
#  'Ken Reitz': 'R',
#  'Ken Retzer': 'L',
#  'Ken Rudolph': 'R',
#  'Ken Singleton': 'B',
#  'Ken Suarez': 'R',
#  'Ken Walters': 'R',
#  'Kevin Bearse': 'L',
#  'Kevin Bell': 'R',
#  'Kevin Mmahat': 'L',
#  'Kevin Stanfield': 'L',
#  'Kiko Garcia': 'R',
#  'Kurt Bevacqua': 'R',
#  'Lafayette Currence': 'B',
#  'Lamar Johnson': 'R',
#  'Larry Anderson': 'R',
#  'Larry Biittner': 'L',
#  'Larry Bowa': 'B',
#  'Larry Brown': 'R',
#  'Larry Cox': 'R',
#  'Larry Dierker': 'R',
#  'Larry Haney': 'R',
#  'Larry Harlow': 'L',
#  'Larry Herndon': 'R',
#  'Larry Hisle': 'R',
#  'Larry Lintz': 'B',
#  'Larry Milbourne': 'B',
#  'Larry Monroe': 'R',
#  'Larry Parrish': 'R',
#  'Larry Pashnick': 'R',
#  'Larry Rothschild': 'L',
#  'Larry Stahl': 'L',
#  'Larvell Blanks': 'R',
#  'Lee Lacy': 'R',
#  'Lee May': 'R',
#  'Lee Mazzilli': 'B',
#  'Lee Thomas': 'L',
#  'Len Gabrielson': 'L',
#  'Len Matuszek': 'L',
#  'Len Randle': 'B',
#  'Len Whitehouse': 'L',
#  'Lenn Sakata': 'R',
#  'Lenny Faedo': 'R',
#  'Leo Cardenas': 'R',
#  'Leon Durham': 'L',
#  'Leon Hooten': 'R',
#  'Leon Roberts': 'R',
#  'Leron Lee': 'L',
#  'Leroy Stanton': 'R',
#  'Les Straker': 'R',
#  'Lou Brock': 'L',
#  'Lou Clinton': 'R',
#  'Lou Johnson': 'R',
#  'Lou Piniella': 'R',
#  'Luis Aguayo': 'R',
#  'Luis Alvarado': 'R',
#  'Luis Aponte': 'R',
#  'Luis Encarnacion': 'R',
#  'Luis Gomez': 'R',
#  'Luis Melendez': 'R',
#  'Luis Pujols': 'R',
#  'Luis Quintana': 'L',
#  'Luis Sanchez': 'R',
#  'Luis Tiant': 'R',
#  'Lyman Bostock': 'L',
#  'Lynn Jones': 'R',
#  'Mack Jones': 'L',
#  'Manny Castillo': 'B',
#  'Manny Jimenez': 'L',
#  'Manny Mota': 'R',
#  'Manny Sanguillen': 'R',
#  'Manny Trillo': 'R',
#  'Marc Hill': 'R',
#  'Mario Guerrero': 'R',
#  'Mario Mendoza': 'R',
#  'Mario Soto': 'R',
#  'Mark Belanger': 'R',
#  'Mark Brouhard': 'R',
#  'Mark Brown': 'B',
#  'Mark Ciardi': 'R',
#  'Mark Clear': 'R',
#  'Mark Esser': 'R',
#  'Mark Mercer': 'L',
#  'Mark Smith': 'R',
#  'Mark Souza': 'L',
#  'Mark Wagner': 'R',
#  'Marty Martinez': 'B',
#  'Marty Perez': 'R',
#  'Marv Breeding': 'R',
#  'Marvell Wynne': 'L',
#  'Matt Williams': 'R',
#  'Matty Alou': 'L',
#  'Max Alvis': 'R',
#  'Mel Stottlemyre': 'R',
#  'Merritt Ranew': 'L',
#  'Merv Rettenmund': 'R',
#  'Mick Kelleher': 'R',
#  'Mickey Brantley': 'R',
#  'Mickey Hatcher': 'R',
#  'Mickey Klutts': 'R',
#  'Mickey Lolich': 'B',
#  'Mickey Rivers': 'L',
#  'Mickey Stanley': 'R',
#  'Miguel Dilone': 'B',
#  'Mike Anderson': 'R',
#  'Mike Andrews': 'R',
#  'Mike Bacsik': 'R',
#  'Mike Brown': 'R',
#  'Mike Brumley': 'L',
#  'Mike Champion': 'R',
#  'Mike Cubbage': 'L',
#  'Mike Darr': 'R',
#  'Mike Davis': 'L',
#  'Mike Diaz': 'R',
#  'Mike Easler': 'L',
#  'Mike Edwards': 'R',
#  'Mike Epstein': 'L',
#  'Mike Fiore': 'L',
#  'Mike Fischlin': 'R',
#  'Mike Hargrove': 'L',
#  'Mike Hegan': 'L',
#  'Mike Hershberger': 'R',
#  'Mike Ivie': 'R',
#  'Mike Jones': 'L',
#  'Mike Jorgensen': 'L',
#  'Mike Kinnunen': 'L',
#  'Mike Krukow': 'R',
#  'Mike Loynd': 'R',
#  'Mike Lum': 'L',
#  'Mike Overy': 'R',
#  'Mike Parrott': 'R',
#  'Mike Paxton': 'R',
#  'Mike Pazik': 'L',
#  'Mike Phillips': 'L',
#  'Mike Ramsey': 'B',
#  'Mike Richardt': 'R',
#  'Mike Rochford': 'L',
#  'Mike Ryan': 'R',
#  'Mike Sadek': 'R',
#  'Mike Schmidt': 'R',
#  'Mike Shannon': 'R',
#  'Mike Smith': 'R',
#  'Mike Smithson': 'L',
#  'Mike Squires': 'L',
#  'Mike Trujillo': 'R',
#  'Mike Tyson': 'R',
#  'Mike Vail': 'R',
#  'Mike Walters': 'R',
#  'Mike Warren': 'R',
#  'Mike Willis': 'L',
#  'Mike Young': 'B',
#  'Mike de la Hoz': 'R',
#  'Milt May': 'L',
#  'Mitchell Page': 'L',
#  'Narciso Elvira': 'L',
#  'Nardi Contreras': 'B',
#  'Nate Colbert': 'R',
#  'Nate Oliver': 'R',
#  'Ned Yost': 'R',
#  'Nelson Mathews': 'R',
#  'Nick Esasky': 'R',
#  'Norm Miller': 'L',
#  'Ollie Brown': 'R',
#  'Omar Moreno': 'L',
#  'Onix Concepcion': 'R',
#  'Orlando Mercado': 'R',
#  'Oscar Gamble': 'L',
#  'Oswaldo Peraza': 'R',
#  'Otto Velez': 'R',
#  'Ozzie Osborn': 'R',
#  'Ozzie Virgil': 'R',
#  'Pat Corrales': 'R',
#  'Pat Kelly': 'L',
#  'Pat Putnam': 'L',
#  'Pat Underwood': 'L',
#  'Paul Blair': 'R',
#  'Paul Boris': 'R',
#  'Paul Casanova': 'R',
#  'Paul Dade': 'R',
#  'Paul Hartzell': 'R',
#  'Paul Householder': 'B',
#  'Paul Mitchell': 'R',
#  'Paul Popovich': 'B',
#  'Paul Schaal': 'R',
#  'Paul Wilmet': 'R',
#  'Pedro Garcia': 'R',
#  'Pedro Gonzalez': 'R',
#  'Pepe Frias': 'R',
#  'Pepe Mangual': 'R',
#  'Pete Filson': 'B',
#  'Pete LaCock': 'L',
#  'Pete Mackanin': 'R',
#  'Pete Rose': 'B',
#  'Pete Ward': 'L',
#  'Phil Bradley': 'R',
#  'Phil Gagliano': 'R',
#  'Phil Garner': 'R',
#  'Phil Huffman': 'R',
#  'Phil Linz': 'R',
#  'Phil Mankowski': 'L',
#  'Phil Niekro': 'R',
#  'Phil Roof': 'R',
#  'R.J. Reynolds': 'B',
#  'Rafael Landestoy': 'B',
#  'Rafael Santana': 'R',
#  'Rafael Vasquez': 'R',
#  'Ralph Botting': 'L',
#  'Ralph Garr': 'L',
#  'Ramon Manon': 'R',
#  'Ramon Pena': 'R',
#  'Randy Hundley': 'R',
#  'Randy Jones': 'R',
#  'Randy Nosek': 'R',
#  'Randy Scarbery': 'B',
#  'Randy Wiles': 'L',
#  'Ray Burris': 'R',
#  'Ray Chadwick': 'B',
#  'Ray Culp': 'R',
#  'Ray Fosse': 'R',
#  'Ray Knight': 'R',
#  'Ray Oyler': 'R',
#  'Ray Sadecki': 'L',
#  'Ray Webster': 'L',
#  'Reggie Jackson': 'L',
#  'Reggie Ritter': 'L',
#  'Reggie Smith': 'B',
#  'Reid Nichols': 'R',
#  'Rennie Stennett': 'R',
#  'Rey Quinones': 'R',
#  'Rich Barnes': 'R',
#  'Rich Chiles': 'L',
#  'Rich Coggins': 'L',
#  'Rich Dauer': 'R',
#  'Rich McKinney': 'R',
#  'Rich Morales': 'R',
#  'Rich Reese': 'L',
#  'Rich Rollins': 'R',
#  'Rich Wortham': 'R',
#  'Rich Yett': 'R',
#  'Richie Hebner': 'L',
#  'Richie Scheinblum': 'B',
#  'Richie Zisk': 'R',
#  'Rick Anderson': 'R',
#  'Rick Auerbach': 'R',
#  'Rick Bosetti': 'R',
#  'Rick Burleson': 'R',
#  'Rick Henninger': 'R',
#  'Rick Jones': 'L',
#  'Rick Joseph': 'R',
#  'Rick Kreuger': 'R',
#  'Rick Leach': 'L',
#  'Rick Lysander': 'R',
#  'Rick Manning': 'L',
#  'Rick Miller': 'L',
#  'Rick Monday': 'L',
#  'Rick Peters': 'B',
#  'Rick Reichardt': 'R',
#  'Rick Renick': 'R',
#  'Rick Rhoden': 'R',
#  'Rick Sofield': 'L',
#  'Rick Steirer': 'R',
#  'Rick Sweet': 'B',
#  'Rick Wise': 'R',
#  'Rickey Keeton': 'R',
#  'Rico Carty': 'R',
#  'Rico Petrocelli': 'R',
#  'Rob Andrews': 'R',
#  'Rob Picciolo': 'R',
#  'Rob Wilfong': 'L',
#  'Rob Woodward': 'R',
#  'Roberto Pena': 'R',
#  'Rod Carew': 'L',
#  'Rod Gilbreath': 'R',
#  'Rod Kanehl': 'R',
#  'Rodney Scott': 'B',
#  'Roger Freed': 'R',
#  'Roger Metzger': 'B',
#  'Roger Miller': 'R',
#  'Roger Repoz': 'L',
#  'Roger Slagle': 'R',
#  'Roger Weaver': 'R',
#  'Ron Blomberg': 'L',
#  'Ron Brand': 'R',
#  'Ron Cey': 'R',
#  'Ron Clark': 'R',
#  'Ron Davis': 'R',
#  'Ron Gardenhire': 'R',
#  'Ron Hodges': 'L',
#  'Ron Hunt': 'R',
#  'Ron Jackson': 'R',
#  'Ron LeFlore': 'R',
#  'Ron Musselman': 'R',
#  'Ron Oester': 'B',
#  'Ron Pruitt': 'R',
#  'Ron Reed': 'R',
#  'Ron Roenicke': 'B',
#  'Ron Romanick': 'R',
#  'Ron Santo': 'R',
#  'Ron Stone': 'L',
#  'Ron Swoboda': 'R',
#  'Ron Theobald': 'R',
#  'Ron Washington': 'R',
#  'Ron Woods': 'R',
#  'Rowland Office': 'L',
#  'Roy Branch': 'R',
#  'Roy Foster': 'R',
#  'Roy Howell': 'L',
#  'Roy Smalley': 'B',
#  'Roy White': 'B',
#  'Rudy Law': 'L',
#  'Rudy Meoli': 'L',
#  'Rufino Linares': 'R',
#  'Ruppert Jones': 'L',
#  'Russ Gibson': 'R',
#  'Rusty Staub': 'L',
#  'Rusty Torres': 'B',
#  'Sal Bando': 'R',
#  'Sal Butera': 'R',
#  'Sam Bowens': 'R',
#  'Sam Hinds': 'R',
#  'Sam McDowell': 'L',
#  'Sandy Alomar': 'B',
#  'Sandy Valdespino': 'L',
#  'Sandy Wihtol': 'R',
#  'Scot Thompson': 'L',
#  'Shawn Holman': 'R',
#  'Sherman Corbett': 'L',
#  'Sixto Lezcano': 'R',
#  'Skip Jutze': 'R',
#  'Sonny Jackson': 'L',
#  'Sonny Siebert': 'R',
#  'Stan Papi': 'R',
#  'Stan Thomas': 'R',
#  'Stefan Wever': 'R',
#  'Steve Adkins': 'R',
#  'Steve Barber': 'L',
#  'Steve Barr': 'L',
#  'Steve Blass': 'R',
#  'Steve Braun': 'L',
#  'Steve Brown': 'R',
#  'Steve Brye': 'R',
#  'Steve Burke': 'B',
#  'Steve Carlton': 'L',
#  'Steve Cummings': 'B',
#  'Steve Curry': 'R',
#  'Steve Davis': 'L',
#  'Steve Dillard': 'R',
#  'Steve Eddy': 'R',
#  'Steve Ellsworth': 'R',
#  'Steve Garvey': 'R',
#  'Steve Henderson': 'R',
#  'Steve Hovley': 'L',
#  'Steve Huntz': 'B',
#  'Steve Jeltz': 'B',
#  'Steve Kemp': 'L',
#  'Steve Lombardozzi': 'R',
#  'Steve Nicosia': 'R',
#  'Steve Ontiveros': 'B',
#  'Steve Renko': 'R',
#  'Steve Rogers': 'R',
#  'Steve Senteney': 'R',
#  'Steve Swisher': 'R',
#  'Steve Whitaker': 'L',
#  'Steve Yeager': 'R',
#  "Syd O'Brien": 'R',
#  'T.R. Bryden': 'R',
#  'Ted Cox': 'R',
#  'Ted Ford': 'R',
#  'Ted Kubiak': 'B',
#  'Ted Martinez': 'R',
#  'Ted Savage': 'R',
#  'Ted Simmons': 'B',
#  'Ted Sizemore': 'R',
#  'Ted Uhlaender': 'L',
#  'Terry Crowley': 'L',
#  'Terry Felton': 'R',
#  'Terry Francona': 'L',
#  'Terry Harmon': 'R',
#  'Terry Harper': 'R',
#  'Terry Humphrey': 'R',
#  'Terry Taylor': 'R',
#  'Terry Whitfield': 'L',
#  'Terry Wilshusen': 'R',
#  'Thad Bosley': 'L',
#  'Thurman Munson': 'R',
#  'Tim Blackwell': 'B',
#  'Tim Corcoran': 'L',
#  'Tim Cullen': 'R',
#  'Tim Flannery': 'L',
#  'Tim Foli': 'R',
#  'Tim Harkness': 'L',
#  'Tim Johnson': 'L',
#  'Tim Laudner': 'R',
#  'Tito Fuentes': 'B',
#  'Tito Landrum': 'R',
#  'Toby Harrah': 'R',
#  'Todd Cruz': 'R',
#  'Todd Fischer': 'R',
#  'Tom Brookens': 'R',
#  'Tom Brown': 'R',
#  'Tom Buskey': 'R',
#  'Tom Dozier': 'R',
#  'Tom Egan': 'R',
#  'Tom Gilles': 'R',
#  'Tom Grieve': 'R',
#  'Tom Haller': 'L',
#  'Tom Hutton': 'L',
#  'Tom Klawitter': 'R',
#  'Tom Lawless': 'R',
#  'Tom Makowski': 'R',
#  'Tom Matchick': 'L',
#  'Tom McCarthy': 'R',
#  'Tom Nieto': 'R',
#  "Tom O'Malley": 'L',
#  'Tom Paciorek': 'R',
#  'Tom Poquette': 'L',
#  'Tom Satriano': 'L',
#  'Tom Seaver': 'R',
#  'Tom Tresh': 'B',
#  'Tom Veryzer': 'R',
#  'Tommie Aaron': 'R',
#  'Tommie Agee': 'R',
#  'Tommie Reynolds': 'R',
#  'Tommy Dean': 'R',
#  'Tommy Harper': 'R',
#  'Tommy Helms': 'R',
#  'Tommy John': 'R',
#  'Tommy McCraw': 'L',
#  'Tony Armas': 'R',
#  'Tony Arnold': 'R',
#  'Tony Chevez': 'R',
#  'Tony Cloninger': 'R',
#  'Tony Conigliaro': 'R',
#  'Tony Ferreira': 'L',
#  'Tony Gonzalez': 'L',
#  'Tony Horton': 'R',
#  'Tony Mack': 'R',
#  'Tony Muser': 'L',
#  'Tony Oliva': 'L',
#  'Tony Perez': 'R',
#  'Tony Scott': 'B',
#  'Tony Solaita': 'L',
#  'Tucker Ashford': 'R',
#  'Ty Cline': 'L',
#  'U L Washington': 'B',
#  'Vance Lovelace': 'L',
#  'Vern Fuller': 'R',
#  'Vic Correll': 'R',
#  'Vic Davalillo': 'L',
#  'Vic Harris': 'B',
#  'Vida Blue': 'B',
#  'Von Joshua': 'L',
#  'Wallace Johnson': 'B',
#  'Walt Bond': 'L',
#  'Walt Williams': 'R',
#  'Wayne Comer': 'R',
#  'Wayne Garrett': 'L',
#  'Wayne Gross': 'L',
#  'Wayne Krenchicki': 'L',
#  'Wayne Nordhagen': 'R',
#  'Wayne Tolleson': 'B',
#  'Wes Parker': 'B',
#  'Wilbur Howard': 'B',
#  'Willie Aikens': 'L',
#  'Willie Crawford': 'L',
#  'Willie Davis': 'L',
#  'Willie Horton': 'R',
#  'Willie Montanez': 'L',
#  'Willie Mueller': 'R',
#  'Willie Norwood': 'R',
#  'Willie Smith': 'L',
#  'Willie Stargell': 'L',
#  'Willie Upshaw': 'L',
#  'Win Remmerswaal': 'R',
#  'Winston Llenas': 'R',
#  'Woodie Fryman': 'R',
#  'Woody Woodward': 'R',
#  'Zach Crouch': 'L',
#  'name': 'handedness'}
